# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51626/Applications-of-data-mining/blob/main/LAB-07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = {
    'Employee': ['John ', 'Sarah', 'Mike','Emma','Tom'],
    'Department': ['IT','HR','IT','Finance','HR'],
    'Salary': ['60000','50000','75000','65000','48000'],
    'Experience (Years)': ['5','3','7','4','2'],
    'Performance Rating (Out of 5)': ['4.5','3.8','4.9','4.2','3.5'],

}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Employee Department Salary Experience (Years) Performance Rating (Out of 5)
# 0    John          IT  60000                  5                           4.5
# 1    Sarah         HR  50000                  3                           3.8
# 2     Mike         IT  75000                  7                           4.9
# 3     Emma    Finance  65000                  4                           4.2
# 4      Tom         HR  48000                  2                           3.5

# %%
df['Salary'] = df['Salary'].astype(int)

average_salary = df.groupby('Department')['Salary'].mean()

average_salary
# Out:
# Department
# Finance    65000.0
# HR         49000.0
# IT         67500.0
# Name: Salary, dtype: float64

# %%
df['Performance Rating (Out of 5)'] = df['Performance Rating (Out of 5)'].astype(float)

high_performers = df[df['Performance Rating (Out of 5)'] > 4.0]
high_performers
# Out:
#   Employee Department  Salary Experience (Years)  \
# 0    John          IT   60000                  5
# 2     Mike         IT   75000                  7
# 3     Emma    Finance   65000                  4
#
#    Performance Rating (Out of 5)
# 0                            4.5
# 2                            4.9
# 3                            4.2

# %%
df['Increment'] = np.where(df['Performance Rating (Out of 5)'] > 4.0,  df['Salary'] * 0.10, df['Salary'] * 0.05)

df['Salary After Increment'] = df['Salary'] + df['Increment']
df
# Out:
#   Employee Department  Salary Experience (Years)  \
# 0    John          IT   60000                  5
# 1    Sarah         HR   50000                  3
# 2     Mike         IT   75000                  7
# 3     Emma    Finance   65000                  4
# 4      Tom         HR   48000                  2
#
#    Performance Rating (Out of 5)  Increment  Salary After Increment
# 0                            4.5     6000.0                 66000.0
# 1                            3.8     2500.0                 52500.0
# 2                            4.9     7500.0                 82500.0
# 3                            4.2     6500.0                 71500.0
# 4                            3.5     2400.0                 50400.0

# %%
sorted_df = df.sort_values(by='Salary After Increment', ascending=False)
sorted_df
# Out:
#   Employee Department  Salary Experience (Years)  \
# 2     Mike         IT   75000                  7
# 3     Emma    Finance   65000                  4
# 0    John          IT   60000                  5
# 1    Sarah         HR   50000                  3
# 4      Tom         HR   48000                  2
#
#    Performance Rating (Out of 5)  Increment  Salary After Increment
# 2                            4.9     7500.0                 82500.0
# 3                            4.2     6500.0                 71500.0
# 0                            4.5     6000.0                 66000.0
# 1                            3.8     2500.0                 52500.0
# 4                            3.5     2400.0                 50400.0

# %% [markdown]
# 2

# %%
data = {
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Miami"],
    "Total Cases": [100000, 85000, 65000, 70000, 55000],
    "Recovered": [75000, 70000, 50000, 60000, 45000],
    "Deaths": [5000, 3500, 2500, 2000, 1500]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#           City  Total Cases  Recovered  Deaths
# 0     New York       100000      75000    5000
# 1  Los Angeles        85000      70000    3500
# 2      Chicago        65000      50000    2500
# 3      Houston        70000      60000    2000
# 4        Miami        55000      45000    1500

# %%
df['Recovery Rate (%)'] = (df['Recovered'] / df['Total Cases']) * 100

# %%
df
# Out:
#           City  Total Cases  Recovered  Deaths  Recovery Rate (%)
# 0     New York       100000      75000    5000          75.000000
# 1  Los Angeles        85000      70000    3500          82.352941
# 2      Chicago        65000      50000    2500          76.923077
# 3      Houston        70000      60000    2000          85.714286
# 4        Miami        55000      45000    1500          81.818182

# %%
df['Death Rate (%)'] = (df['Deaths'] / df['Total Cases']) * 100

df
# Out:
#           City  Total Cases  Recovered  Deaths  Recovery Rate (%)  \
# 0     New York       100000      75000    5000          75.000000
# 1  Los Angeles        85000      70000    3500          82.352941
# 2      Chicago        65000      50000    2500          76.923077
# 3      Houston        70000      60000    2000          85.714286
# 4        Miami        55000      45000    1500          81.818182
#
#    Death Rate (%)
# 0        5.000000
# 1        4.117647
# 2        3.846154
# 3        2.857143
# 4        2.727273

# %%
highcities = df[df['Death Rate (%)'] >3]
highcities
# Out:
#           City  Total Cases  Recovered  Deaths  Recovery Rate (%)  \
# 0     New York       100000      75000    5000          75.000000
# 1  Los Angeles        85000      70000    3500          82.352941
# 2      Chicago        65000      50000    2500          76.923077
#
#    Death Rate (%)
# 0        5.000000
# 1        4.117647
# 2        3.846154

# %%
sorted_recovery = df.sort_values(by='Recovery Rate (%)', ascending=False)
sorted_recovery
# Out:
#           City  Total Cases  Recovered  Deaths  Recovery Rate (%)  \
# 3      Houston        70000      60000    2000          85.714286
# 1  Los Angeles        85000      70000    3500          82.352941
# 4        Miami        55000      45000    1500          81.818182
# 2      Chicago        65000      50000    2500          76.923077
# 0     New York       100000      75000    5000          75.000000
#
#    Death Rate (%)
# 3        2.857143
# 1        4.117647
# 4        2.727273
# 2        3.846154
# 0        5.000000

# %%
total_cases = df['Total Cases'].sum()
print(total_cases)
# Out:
# 375000

# %%
total_deaths = df['Deaths'].sum()
print(total_deaths)
# Out:
# 14500
